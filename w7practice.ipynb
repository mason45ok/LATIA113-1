# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('A_stat_data_112.csv')

# %%
df2 = df.copy()
df2.head()
# Out:
#    grade                      mission_name mission_difficulty mission_field  \
# 0      5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
# 3      5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中          生活知識
# 4      6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易          自然科學
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                    112            112-2
# 1           連續                    112            112-2
# 2           連續                    112            112-2
# 3          非連續                    112            112-2
# 4        連續＋圖表                    112            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# ...

# %%
# Filter the DataFrame where 'mission_difficulty' is "難"
filtered_df = df2[df2["mission_difficulty"] == "難"]

# Loop through the filtered DataFrame and print each row
i = 1
for index, row in filtered_df.iterrows():
    i +=1
    if i == 3:
        break
    else:
        print(filtered_df)
# Out:
#          grade                           mission_name mission_difficulty  \
# 2            6              05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 29           5  06/17 《隨園食單・須知單》（節錄）【多元文化教育－飲食文化】（初階）                  難
# 31           5  06/17 《隨園食單・須知單》（節錄）【多元文化教育－飲食文化】（初階）                  難
# 38           4          06/24 被誤會的塑膠袋？【能源教育－環境保育】（初階）                  難
# 39           6          06/24 被誤會的塑膠袋？【能源教育－環境保育】（初階）                  難
# ...        ...                                    ...                ...
# 1909943      7          04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909946      7          04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909949      7          04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909954      8          04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909956      8          04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# ...

# %%
df2.tail()
# Out:
#          grade                   mission_name mission_difficulty  \
# 1909954      8  04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909955      8    04/22 人與鼠的戰爭【環境教育－動物保育】（中階）                  易
# 1909956      8  04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909957      8           4月特別任務－【SDGs 議題】（中階）                NaN
# 1909958      9           4月特別任務－【SDGs 議題】（中階）                NaN
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# 1909954            議題          非連續                    112            112-2
# 1909955          世界櫥窗           連續                    112            112-2
# 1909956            議題          非連續                    112            112-2
# 1909957           NaN          NaN                    112            112-2
# 1909958           NaN          NaN                    112            112-2
#
#                 mission_datetime_utc8 mission_status  is_completed  ...  \
# ...

# %%
a = df2.columns
a_series = a.to_series()
print(a_series)
a_series.to_csv('work1.csv', index = False)
# Out:
# grade                                                                  grade
# mission_name                                                    mission_name
# mission_difficulty                                        mission_difficulty
# mission_field                                                  mission_field
# mission_type                                                    mission_type
# mission_semester_year                                  mission_semester_year
# mission_semester                                            mission_semester
# mission_datetime_utc8                                  mission_datetime_utc8
# mission_status                                                mission_status
# is_completed                                                    is_completed
# completed_at_utc8                                          completed_at_utc8
# correct_rate                                                    correct_rate
# ...

# %%
b = df2.describe()
print(b)
b.to_excel('bigData.xlsx', index = False)
# Out:
#               grade  mission_semester_year  is_completed   correct_rate  \
# count  1.909959e+06              1909959.0  1.909959e+06  454877.000000
# mean   5.949924e+00                  112.0  2.381606e-01       0.412165
# std    1.586873e+00                    0.0  4.259580e-01       0.317815
# min    4.000000e+00                  112.0  0.000000e+00       0.000000
# 25%    5.000000e+00                  112.0  0.000000e+00       0.200000
# 50%    6.000000e+00                  112.0  0.000000e+00       0.400000
# 75%    7.000000e+00                  112.0  0.000000e+00       0.600000
# max    9.000000e+00                  112.0  1.000000e+00       1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count        453620.000000          1.909959e+06
# mean            147.150187          7.111859e-01
# std             328.610611          1.676427e+00
# min               1.000000          0.000000e+00
# 25%              10.000000          0.000000e+00
# ...

# %%
df2.sort_index(axis=1,ascending=False)
# Out:
#                      user_id mission_type mission_status  \
# 0       -8373966078912715601           連續          已派發任務
# 1        3516683932418412104           連續          已派發任務
# 2         -65799051578279613           連續          已派發任務
# 3       -6293485111595748020          非連續          已派發任務
# 4        4998280410504838977        連續＋圖表          已派發任務
# ...                      ...          ...            ...
# 1909954  5090607127449525741          非連續          已派發任務
# 1909955  1122720388891184818           連續          已派發任務
# 1909956 -3633088233029289359          非連續          已派發任務
# 1909957 -3198336096824660439          NaN          已派發任務
# 1909958  8248998181802054321          NaN          已派發任務
#
#          mission_semester_year mission_semester  \
# 0                          112            112-2
# 1                          112            112-2
# 2                          112            112-2
# 3                          112            112-2
# ...

# %%
df2["mission_status"][0:3]
# Out:
# 0    已派發任務
# 1    已派發任務
# 2    已派發任務
# Name: mission_status, dtype: object

# %%
a = 'grade'
k = df2.duplicated(subset=[a]).sum()
print(k)
# Out:
# 1909953

# %%
# 先按 mission_difficulty 分組，並統計每個分組的數量
difficulty_counts = df2.groupby("grade").size()

# 輸出結果
print(difficulty_counts)
# Out:
# grade
# 4    428520
# 5    438802
# 6    397674
# 7    265140
# 8    204410
# 9    175413
# dtype: int64

# %%
with open("times3.txt",'w',encoding='utf-8') as f:
    f.write(str(difficulty_counts))
    f.close

# %%
df_DiffAndPass = df2[['correct_rate', 'mission_difficulty']].dropna()
df_DiffAndPass.tail()
# Out:
#          correct_rate mission_difficulty
# 1909904           0.4                  難
# 1909905           0.2                  易
# 1909909           0.0                  難
# 1909913           0.2                  易
# 1909917           0.2                  難
